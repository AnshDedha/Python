# %%
a=int(input("Enter first number"))
b=int(input("Enter second number"))
#addition of a and b
print(a+b)
# Out:
# Enter first number 12
# Enter second number 13
# 25

# %%
# subtraction of a and b
print(a-b)
# Out:
# -1

# %%
#floor division
a//b
# Out:
# 0

# %%
#multiplication of a and b
a*b
# Out:
# 156

# %%
# floor division
print(a//b)
# Out:
# 0

# %%
#exponentation
print(a**b)
# Out:
# 106993205379072

# %%
#To interchange
numbers=[10,20,30,40]
temp=numbers[0]
numbers[0]=numbers[-1]
numbers[-1]=temp
print(numbers)
# Out:
# [40, 20, 30, 10]

# %%
a=int(input("Enter first number"))
b=int(input("Enter second number"))
a,b=b,a
print("a =",a)
print("b =",b)
# Out:
# Enter first number 69
# Enter second number 71
# a = 71
# b = 69

# %%
# To add new key:value in dictionary
car_dict={"brand":"range rover","model":"iX","year":1964}
car_dict["color"]="blue"
print(car_dict)
# Out:
# {'brand': 'range rover', 'model': 'iX', 'year': 1964, 'color': 'blue'}

# %%
car_dict={"brand":"range rover","model":"iX","year":1964}
car_dict.pop('year')
print(car_dict)
# Out:
# {'brand': 'range rover', 'model': 'iX'}

# %%
car_dict.copy()
# Out:
# {'brand': 'range rover', 'model': 'iX'}

# %%
myfamily = {
  "child1" : {
    "name" : "Emilie",
    "year" : 2004
  },
  "child2" : {
    "name" : "Ansh",
    "year" : 2007
  },
  "child3" : {
    "name" : "Garvit",
    "year" : 2006
  }
}
